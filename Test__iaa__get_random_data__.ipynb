# %%
import imgaug as ia
from imgaug import augmenters as iaa

from matplotlib.colors import rgb_to_hsv, hsv_to_rgb
import numpy as np
from PIL import Image
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ia.seed(1)

# %%
seq = iaa.SomeOf((2,5),[
    iaa.OneOf([iaa.GaussianBlur(sigma=(0.0,1.0)),iaa.AverageBlur(k=3),iaa.MedianBlur(k=3)]),    
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.1*255), per_channel=0.5),
    iaa.Multiply((0.8, 1.2), per_channel=0.2),
    iaa.Dropout((0.1, 0.2), per_channel=0.5),
    iaa.Add((-20, 20), per_channel=0.5)
],random_order=True)

# %%
def rand(a=0,b=1):
    '''
    create a random value in (a,b]
    :param a: the left bound of the random value
    :param b: the right bound of the random value (not included)
    :return: a random value between (a,b]
    '''
    return np.random.rand()*(b-a)+a

def get_random_data(annotation_line, input_shape, random=True, max_boxes = 20, im_scale_l=0.3, im_scale_r=0.3,im_trans=0.99, hue=.1, sat=1.5, val=1.5,proc_img=True):

    line = annotation_line.split()
    image = Image.open(line[0])
    iw,ih = image.size
    h,w = input_shape
    boxes = np.array([np.array(list(map(int,box.split(',')))) for box in line[1:]])

    if not random:
        # resize image
        scale = min(w/iw, h/ih)
        nw = int(iw*scale)
        nh = int(ih*scale)
        dx = (w-nw)//2
        dy = (h-nh)//2

        new_image = Image.new('RGB', (w,h), (128,128,128))
        image = image.resize((nw,nh), Image.BICUBIC)
        new_image.paste(image, (dx, dy))

        if proc_img:
            image_data = np.array(new_image)/255.
        else:
            image_data = np.array(new_image)

        # correct boxes
        boxes_data = np.zeros((max_boxes,5))
        
        if len(boxes)>0:
            np.random.shuffle(boxes)
            if len(boxes)>max_boxes: boxes = boxes[:max_boxes]
            boxes[:, [0,2]] = boxes[:, [0,2]]*scale + dx
            boxes[:, [1,3]] = boxes[:, [1,3]]*scale + dy
            boxes_data[:len(boxes)] = boxes

        return image_data, boxes_data

    scale = min(w/iw,h/ih)
    scale = rand(1-im_scale_l,1+im_scale_r)*scale
    nw,nh = int(iw*scale),int(ih*scale)
    image = image.resize((nw,nh),Image.BICUBIC)

    im_trans_x = rand(1-im_trans,1+im_trans)
    im_trans_y = rand(1-im_trans,1+im_trans)
    dx = int(im_trans_x*(w-nw)/2.0)
    dy = int(im_trans_y*(h-nh)/2.0)

    new_image = Image.new('RGB', (w,h), (128,128,128))
    new_image.paste(image,(dx,dy))

    image = new_image

    flipped = rand()<0.5
    if flipped:
        image = image.transpose(Image.FLIP_LEFT_RIGHT)

    image = np.array(image)
    image = seq.augment_image(image)
    image_data = image/255.0


    boxes_data = np.zeros((max_boxes,5))

    if len(boxes)>0:
        np.random.shuffle(boxes)
        boxes[:,[0,2]] = boxes[:,[0,2]]*nw/iw + dx
        boxes[:,[1,3]] = boxes[:,[1,3]]*nh/ih + dy
        if flipped:
            boxes[:, [0,2]] = w - boxes[:, [2,0]]

        boxes_w_b = boxes[:, 2] - boxes[:, 0]
        boxes_h_b = boxes[:, 3] - boxes[:, 1]

        boxes[:,0] = np.maximum(boxes[:,0],0)
        boxes[:,1] = np.maximum(boxes[:,1],0)
        boxes[:,2] = np.minimum(boxes[:,2],w-1)
        boxes[:,3] = np.minimum(boxes[:,3],h-1)
        boxes_w_a = boxes[:, 2] - boxes[:, 0]
        boxes_h_a = boxes[:, 3] - boxes[:, 1]

        ratio = (boxes_w_a*boxes_h_a)/(boxes_w_b*boxes_h_b)
        boxes = boxes[ratio>0.40]
        if len(boxes)>max_boxes: boxes = boxes[:max_boxes]
        boxes_data[:len(boxes)] = boxes

    return image_data,boxes_data

# %%
with open('trainval.txt') as f:
    lines = f.readlines()

# %%
for line in lines:
    image,boxes = get_random_data(line,(320,640),random=True)
    image = np.array(image)
    for box in boxes:
        x1,y1,x2,y2,_ =map(int,box)
        image = cv.rectangle(image,(x1,y1),(x2,y2),(255,0,0))
    plt.figure(figsize=(12,12))
    plt.imshow(image)
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for line in lines:
    image,boxes = get_random_data(line,(416,416),random=False)
    image = np.array(image)
    
    if np.max(boxes) > 416:
        for box in boxes:
            x1,y1,x2,y2,_ =map(int,box)
            image = cv.rectangle(image,(x1,y1),(x2,y2),(255,0,0))
        print(line.split()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-d57bb42eb7c2> in <module>()
#       1 for line in lines:
# ----> 2     image,boxes = get_random_data(line,(416,416),random=False)
#       3     image = np.array(image)
#       4
#       5     if np.max(boxes) > 416:
#
# <ipython-input-24-56e0dd13fa43> in get_random_data(annotation_line, input_shape, random, max_boxes, im_scale_l, im_scale_r, im_trans, hue, sat, val, proc_img)
#      29
#      30         if proc_img:
# ---> 31             image_data = np.array(new_image)/255.
#      32         else:
#      33             image_data = np.array(new_image)
#
# KeyboardInterrupt:

# %%
print(np.max(max_nums))
# Out:
# 493.0
